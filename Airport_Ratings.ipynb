# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json

# Google API Key
from config import gkey

# %%
# Import cities file as DataFrame
cities_pd = pd.read_csv("Resources/cities.csv")
cities_pd.head()
# Out:
#             City         State
# 0  New York City      New York
# 1    Los Angeles    California
# 2        Chicago      Illinois
# 3        Houston         Texas
# 4   Philadelphia  Pennsylvania

# %%
# Add columns for lat, lng, airport name, airport address, airport rating
# Note that we used "" to specify initial entry.
cities_pd["Lat"] = ""
cities_pd["Lng"] = ""
cities_pd["Airport Name"] = ""
cities_pd["Airport Address"] = ""
cities_pd["Airport Rating"] = ""
cities_pd.head()
# Out:
#             City         State Lat Lng Airport Name Airport Address  \
# 0  New York City      New York
# 1    Los Angeles    California
# 2        Chicago      Illinois
# 3        Houston         Texas
# 4   Philadelphia  Pennsylvania
#
#   Airport Rating
# 0
# 1
# 2
# 3
# 4

# %%
# create a params dict that will be updated with new city each iteration
params = {"key": gkey}

# Loop through the cities_pd and run a lat/long search for each city
for index, row in cities_pd.iterrows():
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"

    city = row['City']
    state = row['State']

    # update address key value
    params['address'] = f"{city},{state}"

    # make request, print url
    cities_lat_lng = requests.get(base_url, params=params)
    print(cities_lat_lng.url)
    # convert to json
    cities_lat_lng = cities_lat_lng.json()
    print(json.dumps(cities_lat_lng, indent=4))

    cities_pd.loc[index, "Lat"] = cities_lat_lng["results"][0]["geometry"]["location"]["lat"]
    cities_pd.loc[index, "Lng"] = cities_lat_lng["results"][0]["geometry"]["location"]["lng"]

# Visualize to confirm lat lng appear
cities_pd.head()
# Out:
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&address=New+York+City%2CNew+York
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "New York",
#                     "short_name": "New York",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "New York",
#                     "short_name": "NY",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "New York, NY, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 40.9175771,
#                         "lng": -73.70027209999999
#                     },
#                     "southwest": {
#                         "lat": 40.4773991,
#                         "lng": -74.25908989999999
#                     }
#                 },
#                 "location": {
#                     "lat": 40.7127753,
#                     "lng": -74.0059728
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 40.9175771,
#                         "lng": -73.70027209999999
#                     },
#                     "southwest": {
#                         "lat": 40.4773991,
#                         "lng": -74.25908989999999
#                     }
#                 }
#             },
#             "place_id": "ChIJOwg_06VPwokRYv534QaPC8g",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&address=Los+Angeles%2CCalifornia
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Los Angeles",
#                     "short_name": "Los Angeles",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Los Angeles County",
#                     "short_name": "Los Angeles County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "California",
#                     "short_name": "CA",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Los Angeles, CA, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 34.3373061,
#                         "lng": -118.1552891
#                     },
#                     "southwest": {
#                         "lat": 33.7036519,
#                         "lng": -118.6681759
#                     }
#                 },
#                 "location": {
#                     "lat": 34.0522342,
#                     "lng": -118.2436849
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 34.3373061,
#                         "lng": -118.1552891
#                     },
#                     "southwest": {
#                         "lat": 33.7036519,
#                         "lng": -118.6681759
#                     }
#                 }
#             },
#             "place_id": "ChIJE9on3F3HwoAR9AhGJW_fL-I",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&address=Chicago%2CIllinois
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Chicago",
#                     "short_name": "Chicago",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Cook County",
#                     "short_name": "Cook County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Illinois",
#                     "short_name": "IL",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Chicago, IL, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 42.023131,
#                         "lng": -87.52366099999999
#                     },
#                     "southwest": {
#                         "lat": 41.6443349,
#                         "lng": -87.9402669
#                     }
#                 },
#                 "location": {
#                     "lat": 41.8781136,
#                     "lng": -87.6297982
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 42.023131,
#                         "lng": -87.52366099999999
#                     },
#                     "southwest": {
#                         "lat": 41.6443349,
#                         "lng": -87.9402669
#                     }
#                 }
#             },
#             "place_id": "ChIJ7cv00DwsDogRAMDACa2m4K8",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&address=Houston%2CTexas
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Houston",
#                     "short_name": "Houston",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Harris County",
#                     "short_name": "Harris County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Texas",
#                     "short_name": "TX",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Houston, TX, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 30.1107319,
#                         "lng": -95.014496
#                     },
#                     "southwest": {
#                         "lat": 29.523624,
#                         "lng": -95.78808690000001
#                     }
#                 },
#                 "location": {
#                     "lat": 29.7604267,
#                     "lng": -95.3698028
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.1107319,
#                         "lng": -95.014496
#                     },
#                     "southwest": {
#                         "lat": 29.523624,
#                         "lng": -95.78808690000001
#                     }
#                 }
#             },
#             "place_id": "ChIJAYWNSLS4QIYROwVl894CDco",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&address=Philadelphia%2CPennsylvania
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Philadelphia",
#                     "short_name": "Philadelphia",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Philadelphia County",
#                     "short_name": "Philadelphia County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Pennsylvania",
#                     "short_name": "PA",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Philadelphia, PA, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 40.1379919,
#                         "lng": -74.9557629
#                     },
#                     "southwest": {
#                         "lat": 39.8670041,
#                         "lng": -75.280303
#                     }
#                 },
#                 "location": {
#                     "lat": 39.9525839,
#                     "lng": -75.1652215
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 40.1379919,
#                         "lng": -74.9557629
#                     },
#                     "southwest": {
#                         "lat": 39.8670041,
#                         "lng": -75.280303
#                     }
#                 }
#             },
#             "place_id": "ChIJ60u11Ni3xokRwVg-jNgU9Yk",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&address=Phoenix%2CArizona
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Phoenix",
#                     "short_name": "Phoenix",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Maricopa County",
#                     "short_name": "Maricopa County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Arizona",
#                     "short_name": "AZ",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Phoenix, AZ, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 33.92057,
#                         "lng": -111.926046
#                     },
#                     "southwest": {
#                         "lat": 33.29025980000001,
#                         "lng": -112.324056
#                     }
#                 },
#                 "location": {
#                     "lat": 33.4483771,
#                     "lng": -112.0740373
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.92057,
#                         "lng": -111.926046
#                     },
#                     "southwest": {
#                         "lat": 33.29025980000001,
#                         "lng": -112.324056
#                     }
#                 }
#             },
#             "place_id": "ChIJy3mhUO0SK4cRrBtKNfjHaYw",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&address=San+Antonio%2CTexas
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "San Antonio",
#                     "short_name": "San Antonio",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Bexar County",
#                     "short_name": "Bexar County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Texas",
#                     "short_name": "TX",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "San Antonio, TX, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 29.73872,
#                         "lng": -98.22295799999999
#                     },
#                     "southwest": {
#                         "lat": 29.2241411,
#                         "lng": -98.8058509
#                     }
#                 },
#                 "location": {
#                     "lat": 29.4241219,
#                     "lng": -98.49362819999999
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.73872,
#                         "lng": -98.22295799999999
#                     },
#                     "southwest": {
#                         "lat": 29.2241411,
#                         "lng": -98.8058509
#                     }
#                 }
#             },
#             "place_id": "ChIJrw7QBK9YXIYRvBagEDvhVgg",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&address=San+Diego%2CCalifornia
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "San Diego",
#                     "short_name": "San Diego",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "San Diego County",
#                     "short_name": "San Diego County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "California",
#                     "short_name": "CA",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "San Diego, CA, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 33.114249,
#                         "lng": -116.90816
#                     },
#                     "southwest": {
#                         "lat": 32.534856,
#                         "lng": -117.3097969
#                     }
#                 },
#                 "location": {
#                     "lat": 32.715738,
#                     "lng": -117.1610838
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.114249,
#                         "lng": -116.90816
#                     },
#                     "southwest": {
#                         "lat": 32.534856,
#                         "lng": -117.3097969
#                     }
#                 }
#             },
#             "place_id": "ChIJSx6SrQ9T2YARed8V_f0hOg0",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&address=Dallas%2CTexas
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Dallas",
#                     "short_name": "Dallas",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Dallas County",
#                     "short_name": "Dallas County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Texas",
#                     "short_name": "TX",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Dallas, TX, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 33.0237921,
#                         "lng": -96.4637379
#                     },
#                     "southwest": {
#                         "lat": 32.617537,
#                         "lng": -96.999347
#                     }
#                 },
#                 "location": {
#                     "lat": 32.7766642,
#                     "lng": -96.79698789999999
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.0237921,
#                         "lng": -96.4637379
#                     },
#                     "southwest": {
#                         "lat": 32.617537,
#                         "lng": -96.999347
#                     }
#                 }
#             },
#             "place_id": "ChIJS5dFe_cZTIYRj2dH9qSb7Lk",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&address=San+Jose%2CCalifornia
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "San Jose",
#                     "short_name": "San Jose",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Santa Clara County",
#                     "short_name": "Santa Clara County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "California",
#                     "short_name": "CA",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "San Jose, CA, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 37.4695381,
#                         "lng": -121.589154
#                     },
#                     "southwest": {
#                         "lat": 37.124493,
#                         "lng": -122.0456719
#                     }
#                 },
#                 "location": {
#                     "lat": 37.3382082,
#                     "lng": -121.8863286
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.4695381,
#                         "lng": -121.589154
#                     },
#                     "southwest": {
#                         "lat": 37.124493,
#                         "lng": -122.0456719
#                     }
#                 }
#             },
#             "place_id": "ChIJ9T_5iuTKj4ARe3GfygqMnbk",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&address=Austin%2CTexas
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Austin",
#                     "short_name": "Austin",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Travis County",
#                     "short_name": "Travis County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Texas",
#                     "short_name": "TX",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Austin, TX, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 30.5168629,
#                         "lng": -97.5684199
#                     },
#                     "southwest": {
#                         "lat": 30.0986589,
#                         "lng": -97.9383829
#                     }
#                 },
#                 "location": {
#                     "lat": 30.267153,
#                     "lng": -97.7430608
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.5168629,
#                         "lng": -97.5684199
#                     },
#                     "southwest": {
#                         "lat": 30.0986589,
#                         "lng": -97.9383829
#                     }
#                 }
#             },
#             "place_id": "ChIJLwPMoJm1RIYRetVp1EtGm10",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&address=Jacksonville%2CFlorida
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Jacksonville",
#                     "short_name": "Jacksonville",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Duval County",
#                     "short_name": "Duval County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Florida",
#                     "short_name": "FL",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Jacksonville, FL, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 30.586232,
#                         "lng": -81.316712
#                     },
#                     "southwest": {
#                         "lat": 30.103748,
#                         "lng": -82.0495018
#                     }
#                 },
#                 "location": {
#                     "lat": 30.3321838,
#                     "lng": -81.65565099999999
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.586232,
#                         "lng": -81.316712
#                     },
#                     "southwest": {
#                         "lat": 30.103748,
#                         "lng": -82.0495018
#                     }
#                 }
#             },
#             "place_id": "ChIJ66_O8Ra35YgR4sf8ljh9zcQ",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&address=San+Francisco%2CCalifornia
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "San Francisco",
#                     "short_name": "SF",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "San Francisco County",
#                     "short_name": "San Francisco County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "California",
#                     "short_name": "CA",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "San Francisco, CA, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 37.9298239,
#                         "lng": -122.28178
#                     },
#                     "southwest": {
#                         "lat": 37.6398299,
#                         "lng": -123.173825
#                     }
#                 },
#                 "location": {
#                     "lat": 37.7749295,
#                     "lng": -122.4194155
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.812,
#                         "lng": -122.3482
#                     },
#                     "southwest": {
#                         "lat": 37.70339999999999,
#                         "lng": -122.527
#                     }
#                 }
#             },
#             "place_id": "ChIJIQBpAG2ahYAR_6128GcTUEo",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&address=Indianapolis%2CIndiana
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Indianapolis",
#                     "short_name": "Indianapolis",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Marion County",
#                     "short_name": "Marion County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Indiana",
#                     "short_name": "IN",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Indianapolis, IN, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 39.927392,
#                         "lng": -85.9373789
#                     },
#                     "southwest": {
#                         "lat": 39.632177,
#                         "lng": -86.32812109999999
#                     }
#                 },
#                 "location": {
#                     "lat": 39.768403,
#                     "lng": -86.158068
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.927392,
#                         "lng": -85.9373789
#                     },
#                     "southwest": {
#                         "lat": 39.632177,
#                         "lng": -86.32812109999999
#                     }
#                 }
#             },
#             "place_id": "ChIJA2p5p_9Qa4gRfOq5QPadjtY",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&address=Columbus%2COhio
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Columbus",
#                     "short_name": "Columbus",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Franklin County",
#                     "short_name": "Franklin County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Ohio",
#                     "short_name": "OH",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Columbus, OH, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 40.1572719,
#                         "lng": -82.77137809999999
#                     },
#                     "southwest": {
#                         "lat": 39.808631,
#                         "lng": -83.2102799
#                     }
#                 },
#                 "location": {
#                     "lat": 39.9611755,
#                     "lng": -82.99879419999999
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 40.1572719,
#                         "lng": -82.77137809999999
#                     },
#                     "southwest": {
#                         "lat": 39.808631,
#                         "lng": -83.2102799
#                     }
#                 }
#             },
#             "place_id": "ChIJcd6QucGJOIgRM7Wxz_hmMuQ",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&address=Fort+Worth%2CTexas
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Fort Worth",
#                     "short_name": "Fort Worth",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Tarrant County",
#                     "short_name": "Tarrant County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Texas",
#                     "short_name": "TX",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Fort Worth, TX, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 33.0493109,
#                         "lng": -97.033715
#                     },
#                     "southwest": {
#                         "lat": 32.552315,
#                         "lng": -97.54492289999999
#                     }
#                 },
#                 "location": {
#                     "lat": 32.7554883,
#                     "lng": -97.3307658
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 33.0493109,
#                         "lng": -97.033715
#                     },
#                     "southwest": {
#                         "lat": 32.552315,
#                         "lng": -97.54492289999999
#                     }
#                 }
#             },
#             "place_id": "ChIJrQfILRJuToYRvaxp3fiLr6Q",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&address=Charlotte%2CNorth+Carolina
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Charlotte",
#                     "short_name": "Charlotte",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "1, Charlotte",
#                     "short_name": "1, Charlotte",
#                     "types": [
#                         "administrative_area_level_3",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Mecklenburg County",
#                     "short_name": "Mecklenburg County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "North Carolina",
#                     "short_name": "NC",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Charlotte, NC, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 35.39313300000001,
#                         "lng": -80.670104
#                     },
#                     "southwest": {
#                         "lat": 35.0131739,
#                         "lng": -81.0095539
#                     }
#                 },
#                 "location": {
#                     "lat": 35.2270869,
#                     "lng": -80.8431267
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 35.39313300000001,
#                         "lng": -80.670104
#                     },
#                     "southwest": {
#                         "lat": 35.0131739,
#                         "lng": -81.0095539
#                     }
#                 }
#             },
#             "place_id": "ChIJgRo4_MQfVIgRZNFDv-ZQRog",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&address=Seattle%2CWashington
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Seattle",
#                     "short_name": "Seattle",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "King County",
#                     "short_name": "King County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Washington",
#                     "short_name": "WA",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Seattle, WA, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 47.734145,
#                         "lng": -122.2244331
#                     },
#                     "southwest": {
#                         "lat": 47.4919119,
#                         "lng": -122.4596959
#                     }
#                 },
#                 "location": {
#                     "lat": 47.6062095,
#                     "lng": -122.3320708
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.734145,
#                         "lng": -122.2244331
#                     },
#                     "southwest": {
#                         "lat": 47.4919119,
#                         "lng": -122.4596959
#                     }
#                 }
#             },
#             "place_id": "ChIJVTPokywQkFQRmtVEaUZlJRA",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&address=Denver%2CColorado
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Denver",
#                     "short_name": "Denver",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Denver County",
#                     "short_name": "Denver County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Colorado",
#                     "short_name": "CO",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Denver, CO, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 39.91424689999999,
#                         "lng": -104.6002959
#                     },
#                     "southwest": {
#                         "lat": 39.614431,
#                         "lng": -105.109927
#                     }
#                 },
#                 "location": {
#                     "lat": 39.7392358,
#                     "lng": -104.990251
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 39.91424689999999,
#                         "lng": -104.6002959
#                     },
#                     "southwest": {
#                         "lat": 39.614431,
#                         "lng": -105.109927
#                     }
#                 }
#             },
#             "place_id": "ChIJzxcfI6qAa4cR1jaKJ_j0jhE",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&address=El+Paso%2CTexas
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "El Paso",
#                     "short_name": "El Paso",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "El Paso County",
#                     "short_name": "El Paso County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Texas",
#                     "short_name": "TX",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "El Paso, TX, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 32.001481,
#                         "lng": -106.2131129
#                     },
#                     "southwest": {
#                         "lat": 31.6207851,
#                         "lng": -106.6359219
#                     }
#                 },
#                 "location": {
#                     "lat": 31.7618778,
#                     "lng": -106.4850217
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.001481,
#                         "lng": -106.2131129
#                     },
#                     "southwest": {
#                         "lat": 31.6207851,
#                         "lng": -106.6359219
#                     }
#                 }
#             },
#             "place_id": "ChIJaTv-xYs_54YRIgKdq-OEkeM",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&address=Detroit%2CMichigan
# {
#     "results": [
#         {
# ...
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Chesapeake, VA, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 36.866549,
#                         "lng": -76.065553
#                     },
#                     "southwest": {
#                         "lat": 36.550447,
#                         "lng": -76.491497
#                     }
#                 },
#                 "location": {
#                     "lat": 36.7682088,
#                     "lng": -76.2874927
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 36.866549,
#                         "lng": -76.065553
#                     },
#                     "southwest": {
#                         "lat": 36.550447,
#                         "lng": -76.491497
#                     }
#                 }
#             },
#             "place_id": "ChIJmW0vgHqluokReQtxkBcbe0w",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&address=North+Las+Vegas%2CNevada
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "North Las Vegas",
#                     "short_name": "North Las Vegas",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Clark County",
#                     "short_name": "Clark County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Nevada",
#                     "short_name": "NV",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "North Las Vegas, NV, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 36.33589,
#                         "lng": -114.9586219
#                     },
#                     "southwest": {
#                         "lat": 36.184827,
#                         "lng": -115.2121
#                     }
#                 },
#                 "location": {
#                     "lat": 36.1988592,
#                     "lng": -115.1175013
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 36.33589,
#                         "lng": -114.9586219
#                     },
#                     "southwest": {
#                         "lat": 36.184827,
#                         "lng": -115.2121
#                     }
#                 }
#             },
#             "place_id": "ChIJMz3UCrDCyIARJvWs9RP6xyI",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&address=Fremont%2CCalifornia
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Fremont",
#                     "short_name": "Fremont",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Alameda County",
#                     "short_name": "Alameda County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "California",
#                     "short_name": "CA",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Fremont, CA, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 37.604234,
#                         "lng": -121.867767
#                     },
#                     "southwest": {
#                         "lat": 37.4545388,
#                         "lng": -122.1491751
#                     }
#                 },
#                 "location": {
#                     "lat": 37.5482697,
#                     "lng": -121.9885719
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.604234,
#                         "lng": -121.867767
#                     },
#                     "southwest": {
#                         "lat": 37.4545388,
#                         "lng": -122.1491751
#                     }
#                 }
#             },
#             "place_id": "ChIJ98rot0a_j4AR1IjYiTsx2oo",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&address=Baton+Rouge%2CLouisiana
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Baton Rouge",
#                     "short_name": "Baton Rouge",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "East Baton Rouge Parish",
#                     "short_name": "East Baton Rouge Parish",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Louisiana",
#                     "short_name": "LA",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Baton Rouge, LA, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 30.5592161,
#                         "lng": -91.0010191
#                     },
#                     "southwest": {
#                         "lat": 30.3237319,
#                         "lng": -91.221818
#                     }
#                 },
#                 "location": {
#                     "lat": 30.4514677,
#                     "lng": -91.18714659999999
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.5592161,
#                         "lng": -91.0010191
#                     },
#                     "southwest": {
#                         "lat": 30.3237319,
#                         "lng": -91.221818
#                     }
#                 }
#             },
#             "place_id": "ChIJy3RfMmc4JIYRHZpXkdvxIyE",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&address=Richmond%2CVirginia
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Richmond",
#                     "short_name": "Richmond",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Virginia",
#                     "short_name": "VA",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Richmond, VA, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 37.6027689,
#                         "lng": -77.3855119
#                     },
#                     "southwest": {
#                         "lat": 37.446553,
#                         "lng": -77.601011
#                     }
#                 },
#                 "location": {
#                     "lat": 37.5407246,
#                     "lng": -77.4360481
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.6027689,
#                         "lng": -77.3855119
#                     },
#                     "southwest": {
#                         "lat": 37.446553,
#                         "lng": -77.601011
#                     }
#                 }
#             },
#             "place_id": "ChIJ7cmZVwkRsYkRxTxC4m0-2L8",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&address=Boise%2CIdaho
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Boise",
#                     "short_name": "Boise",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Ada County",
#                     "short_name": "Ada County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Idaho",
#                     "short_name": "ID",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Boise, ID, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 43.6898951,
#                         "lng": -116.1019091
#                     },
#                     "southwest": {
#                         "lat": 43.511717,
#                         "lng": -116.3658869
#                     }
#                 },
#                 "location": {
#                     "lat": 43.6187102,
#                     "lng": -116.2146068
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.6898951,
#                         "lng": -116.1019091
#                     },
#                     "southwest": {
#                         "lat": 43.511717,
#                         "lng": -116.3658869
#                     }
#                 }
#             },
#             "place_id": "ChIJnbRH6XLxrlQRm51nNpuYW5o",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&address=San+Bernardino%2CCalifornia
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "San Bernardino",
#                     "short_name": "San Bernardino",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "San Bernardino County",
#                     "short_name": "San Bernardino County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "California",
#                     "short_name": "CA",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "San Bernardino, CA, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 34.2476399,
#                         "lng": -117.164972
#                     },
#                     "southwest": {
#                         "lat": 34.0501128,
#                         "lng": -117.4243172
#                     }
#                 },
#                 "location": {
#                     "lat": 34.1083449,
#                     "lng": -117.2897652
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 34.2476399,
#                         "lng": -117.164972
#                     },
#                     "southwest": {
#                         "lat": 34.0501128,
#                         "lng": -117.4243172
#                     }
#                 }
#             },
#             "place_id": "ChIJ87j94n1Tw4ARjcKHjHjGZyg",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
#             City         State      Lat      Lng Airport Name Airport Address  \
# 0  New York City      New York  40.7128  -74.006
# 1    Los Angeles    California  34.0522 -118.244
# 2        Chicago      Illinois  41.8781 -87.6298
# 3        Houston         Texas  29.7604 -95.3698
# 4   Philadelphia  Pennsylvania  39.9526 -75.1652
#
#   Airport Rating
# 0
# 1
# 2
# 3
# 4

# %%
# params dictionary to update each iteration
params = {
    "radius": 50000,
    "types": "airport",
    "keyword": "international airport",
    "key": gkey
}

# Use the lat/lng we recovered to identify airports
for index, row in cities_pd.iterrows():
    # get lat, lng from df
    lat = row["Lat"]
    lng = row["Lng"]

    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"

    # Use the search term: "International Airport" and our lat/lng
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # make request and print url
    name_address = requests.get(base_url, params=params)
    print(name_address.url)

    # convert to json
    name_address = name_address.json()
    # print(json.dumps(name_address, indent=4, sort_keys=True))

    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        cities_pd.loc[index, "Airport Name"] = name_address["results"][0]["name"]
        cities_pd.loc[index, "Airport Address"] = name_address["results"][0]["vicinity"]
        cities_pd.loc[index, "Airport Rating"] = name_address["results"][0]["rating"]
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=40.7127753%2C-74.0059728
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=34.0522342%2C-118.2436849
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=41.8781136%2C-87.6297982
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=29.7604267%2C-95.3698028
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=39.9525839%2C-75.1652215
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=33.4483771%2C-112.0740373
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=29.4241219%2C-98.49362819999999
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=32.715738%2C-117.1610838
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=32.7766642%2C-96.79698789999999
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=37.3382082%2C-121.8863286
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=30.267153%2C-97.7430608
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=30.3321838%2C-81.65565099999999
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=37.7749295%2C-122.4194155
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=39.768403%2C-86.158068
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=39.9611755%2C-82.99879419999999
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=32.7554883%2C-97.3307658
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=35.2270869%2C-80.8431267
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=47.6062095%2C-122.3320708
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=39.7392358%2C-104.990251
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=31.7618778%2C-106.4850217
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=42.331427%2C-83.0457538
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=38.9071923%2C-77.0368707
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=42.3600825%2C-71.0588801
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=35.1495343%2C-90.0489801
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=36.1626638%2C-86.7816016
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=45.5230622%2C-122.6764815
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=35.4675602%2C-97.5164276
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=36.1699412%2C-115.1398296
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=39.2903848%2C-76.6121893
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=38.2526647%2C-85.7584557
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=43.0389025%2C-87.9064736
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=35.0843859%2C-106.650422
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=32.2226066%2C-110.9747108
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=36.7377981%2C-119.7871247
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=38.5815719%2C-121.4943996
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=39.0997265%2C-94.5785667
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=33.7700504%2C-118.1937395
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=33.4151843%2C-111.8314724
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=33.7489954%2C-84.3879824
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=38.8338816%2C-104.8213634
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=36.8529263%2C-75.97798499999999
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=35.7795897%2C-78.6381787
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=41.2565369%2C-95.9345034
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=25.7616798%2C-80.1917902
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=37.8043637%2C-122.2711137
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=44.977753%2C-93.2650108
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=36.1539816%2C-95.99277500000001
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=37.68717609999999%2C-97.33005299999999
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=29.95106579999999%2C-90.0715323
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=32.735687%2C-97.10806559999999
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=41.49932%2C-81.6943605
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=35.3732921%2C-119.0187125
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=27.950575%2C-82.4571776
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=39.7294319%2C-104.8319195
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=21.3069444%2C-157.8583333
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=33.8365932%2C-117.9143012
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=33.7454725%2C-117.867653
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=27.8005828%2C-97.39638099999999
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=33.9806005%2C-117.3754942
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=38.6270025%2C-90.19940419999999
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=38.0405837%2C-84.5037164
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=37.9577016%2C-121.2907796
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=40.44062479999999%2C-79.9958864
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=44.9537029%2C-93.0899578
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=61.2180556%2C-149.9002778
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=39.1031182%2C-84.5120196
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=36.0395247%2C-114.9817213
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=36.0726354%2C-79.7919754
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=33.0198431%2C-96.6988856
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=40.735657%2C-74.1723667
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=41.6528052%2C-83.5378674
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=40.813616%2C-96.7025955
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=28.5383355%2C-81.3792365
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=32.6400541%2C-117.0841955
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=40.72815749999999%2C-74.0776417
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=33.3061605%2C-111.8412502
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=41.079273%2C-85.1393513
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=42.88644679999999%2C-78.8783689
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=35.9940329%2C-78.898619
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=27.7676008%2C-82.64029149999999
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=33.6845673%2C-117.8265049
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=27.5305671%2C-99.48032409999999
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=33.5778631%2C-101.8551665
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=43.0730517%2C-89.4012302
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=33.3528264%2C-111.789027
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=36.8507689%2C-76.28587259999999
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=39.5296329%2C-119.8138027
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=36.09985959999999%2C-80.244216
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=33.5386523%2C-112.1859866
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=25.8575963%2C-80.2781057
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=32.912624%2C-96.63888329999999
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=33.4941704%2C-111.9260519
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=32.8140177%2C-96.9488945
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=36.7682088%2C-76.2874927
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=36.1988592%2C-115.1175013
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=37.5482697%2C-121.9885719
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=30.4514677%2C-91.18714659999999
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=37.5407246%2C-77.4360481
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=43.6187102%2C-116.2146068
# Missing field/result... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=50000&types=airport&keyword=international+airport&key=AIzaSyBpyaMjX2MG-plXlLDA0NzyNR0drBCAra8&location=34.1083449%2C-117.2897652

# %%
# Save Data to csv
cities_pd.to_csv("Airport_Output.csv")

# Visualize to confirm airport data appears
cities_pd
# Out:
#                City                 State      Lat      Lng  \
# 0     New York City              New York  40.7128  -74.006
# 1       Los Angeles            California  34.0522 -118.244
# 2           Chicago              Illinois  41.8781 -87.6298
# 3           Houston                 Texas  29.7604 -95.3698
# 4      Philadelphia          Pennsylvania  39.9526 -75.1652
# 5           Phoenix               Arizona  33.4484 -112.074
# 6       San Antonio                 Texas  29.4241 -98.4936
# 7         San Diego            California  32.7157 -117.161
# 8            Dallas                 Texas  32.7767  -96.797
# 9          San Jose            California  37.3382 -121.886
# 10           Austin                 Texas  30.2672 -97.7431
# 11     Jacksonville               Florida  30.3322 -81.6557
# 12    San Francisco            California  37.7749 -122.419
# 13     Indianapolis               Indiana  39.7684 -86.1581
# 14         Columbus                  Ohio  39.9612 -82.9988
# 15       Fort Worth                 Texas  32.7555 -97.3308
# 16        Charlotte        North Carolina  35.2271 -80.8431
# 17          Seattle            Washington  47.6062 -122.332
# 18           Denver              Colorado  39.7392  -104.99
# 19          El Paso                 Texas  31.7619 -106.485
# 20          Detroit              Michigan  42.3314 -83.0458
# 21       Washington  District of Columbia  38.9072 -77.0369
# 22           Boston         Massachusetts  42.3601 -71.0589
# 23          Memphis             Tennessee  35.1495  -90.049
# 24        Nashville             Tennessee  36.1627 -86.7816
# 25         Portland                Oregon  45.5231 -122.676
# 26    Oklahoma City              Oklahoma  35.4676 -97.5164
# 27        Las Vegas                Nevada  36.1699  -115.14
# 28        Baltimore              Maryland  39.2904 -76.6122
# 29       Louisville              Kentucky  38.2527 -85.7585
# ..              ...                   ...      ...      ...
# 70           Toledo                  Ohio  41.6528 -83.5379
# 71          Lincoln              Nebraska  40.8136 -96.7026
# 72          Orlando               Florida  28.5383 -81.3792
# 73      Chula Vista            California  32.6401 -117.084
# 74      Jersey City            New Jersey  40.7282 -74.0776
# 75         Chandler               Arizona  33.3062 -111.841
# 76       Fort Wayne               Indiana  41.0793 -85.1394
# 77          Buffalo              New York  42.8864 -78.8784
# 78           Durham        North Carolina   35.994 -78.8986
# 79   St. Petersburg               Florida  27.7676 -82.6403
# 80           Irvine            California  33.6846 -117.827
# 81           Laredo                 Texas  27.5306 -99.4803
# 82          Lubbock                 Texas  33.5779 -101.855
# 83          Madison             Wisconsin  43.0731 -89.4012
# 84          Gilbert               Arizona  33.3528 -111.789
# 85          Norfolk              Virginia  36.8508 -76.2859
# 86             Reno                Nevada  39.5296 -119.814
# 87    Winston-Salem        North Carolina  36.0999 -80.2442
# 88         Glendale               Arizona  33.5387 -112.186
# 89          Hialeah               Florida  25.8576 -80.2781
# 90          Garland                 Texas  32.9126 -96.6389
# 91       Scottsdale               Arizona  33.4942 -111.926
# 92           Irving                 Texas   32.814 -96.9489
# 93       Chesapeake              Virginia  36.7682 -76.2875
# 94  North Las Vegas                Nevada  36.1989 -115.118
# 95          Fremont            California  37.5483 -121.989
# 96      Baton Rouge             Louisiana  30.4515 -91.1871
# 97         Richmond              Virginia  37.5407  -77.436
# 98            Boise                 Idaho  43.6187 -116.215
# 99   San Bernardino            California  34.1083  -117.29
#
#                                          Airport Name  \
# 0                Newark Liberty International Airport
# 1                   Los Angeles International Airport
# 2                        O'Hare International Airport
# 3                George Bush Intercontinental Airport
# 4                  Philadelphia International Airport
# 5            Phoenix Sky Harbor International Airport
# 6                   San Antonio International Airport
# 7                     San Diego International Airport
# 8             Dallas/Fort Worth International Airport
# 9                 San Francisco International Airport
# 10             Austin-Bergstrom International Airport
# 11                 Jacksonville International Airport
# 12                San Francisco International Airport
# 13                 Indianapolis International Airport
# 14          John Glenn Columbus International Airport
# 15            Dallas/Fort Worth International Airport
# 16            Charlotte Douglas International Airport
# 17               Seattle-Tacoma International Airport
# 18                       Denver International Airport
# 19                      El Paso International Airport
# 20          Detroit Metropolitan Wayne County Airport
# 21                       Dulles International Airport
# 22                 Boston Logan International Airport
# 23                      Memphis International Airport
# 24                    Nashville International Airport
# 25                     Portland International Airport
# 26                          Will Rogers World Airport
# 27                     McCarran International Airport
# 28  Baltimore/Washington International Thurgood Ma...
# 29                   Louisville International Airport
# ..                                                ...
# 70                             Toledo Express Airport
# 71                                    Lincoln Airport
# 72                      Orlando International Airport
# 73                    San Diego International Airport
# 74               Newark Liberty International Airport
# 75           Phoenix Sky Harbor International Airport
# 76                   Fort Wayne International Airport
# 77              Buffalo Niagara International Airport
# 78               Raleigh-Durham International Airport
# 79                        Tampa International Airport
# 80                      Ontario International Airport
# 81                       Laredo International Airport
# 82        Lubbock Preston Smith International Airport
# 83                       Dane County Regional Airport
# 84           Phoenix Sky Harbor International Airport
# 85                      Norfolk International Airport
# 86                   Reno-Tahoe International Airport
# 87               Piedmont Triad International Airport
# 88           Phoenix Sky Harbor International Airport
# 89                        Miami International Airport
# 90            Dallas/Fort Worth International Airport
# 91           Phoenix Sky Harbor International Airport
# 92            Dallas/Fort Worth International Airport
# 93                      Norfolk International Airport
# 94                     McCarran International Airport
# 95                San Francisco International Airport
# 96                   Baton Rouge Metropolitan Airport
# 97                     Richmond International Airport
# 98                  Eckhart International Airport-1S1
# 99                      Ontario International Airport
#
#                                      Airport Address Airport Rating
# 0                              3 Brewster Rd, Newark            3.2
# 1                           1 World Way, Los Angeles            3.5
# 2                        10000 W O'Hare Ave, Chicago            3.6
# 3                        2800 N Terminal Rd, Houston            3.7
# 4                   8000 Essington Ave, Philadelphia            3.3
# 5                    3400 E Sky Harbor Blvd, Phoenix            3.9
# 6                     9800 Airport Blvd, San Antonio              4
# 7                        3225 N Harbor Dr, San Diego            3.9
# 8                      2400 Aviation Dr, DFW Airport            3.8
# 9                                      San Francisco            4.1
# 10                    3600 Presidential Blvd, Austin              4
# 11              2400 Yankee Clipper Dr, Jacksonville            4.2
# 12                                     San Francisco            4.1
# 13  7800 Col. H. Weir Cook Memorial Dr, Indianapolis            4.3
# 14              4600 International Gateway, Columbus            3.9
# 15                     2400 Aviation Dr, DFW Airport            3.8
# 16              5501 Josh Birmingham Pkwy, Charlotte            3.5
# 17                 17801 International Blvd, Seattle            3.8
# 18                            8500 Peña Blvd, Denver              4
# 19                          6701 Convair Rd, El Paso            4.2
# 20                                           Detroit            4.1
# 21                            1 Saarinen Cir, Dulles            3.9
# 22                           1 Harborside Dr, Boston            3.9
# 23                       2491 Winchester Rd, Memphis            3.6
# 24                          1 Terminal Dr, Nashville            4.1
# 25                     7000 NE Airport Way, Portland            4.5
# 26                   7100 Terminal Dr, Oklahoma City            4.2
# 27                 5757 Wayne Newton Blvd, Las Vegas            3.9
# 28                                         Baltimore              4
# 29                       600 Terminal Dr, Louisville              4
# ..                                               ...            ...
# 70                    11013 Airport Hwy #11, Swanton            3.8
# 71                          2400 W Adams St, Lincoln            3.5
# 72                        1 Jeff Fuqua Blvd, Orlando            3.7
# 73                       3225 N Harbor Dr, San Diego            3.9
# 74                             3 Brewster Rd, Newark            3.2
# 75                   3400 E Sky Harbor Blvd, Phoenix            3.9
# 76                    3801 W Ferguson Rd, Fort Wayne            3.7
# 77                          4200 Genesee St, Buffalo            4.1
# 78              2400 John Brantley Blvd, Morrisville            4.2
# 79                    4100 George J Bean Pkwy, Tampa            4.4
# 80                                           Ontario            4.2
# 81                     5210 Bob Bullock Loop, Laredo              4
# 82                5401 N Martin L King Blvd, Lubbock            3.8
# 83                    4000 International Ln, Madison            4.1
# 84                   3400 E Sky Harbor Blvd, Phoenix            3.9
# 85                         2200 Norview Ave, Norfolk            3.6
# 86                             2001 E Plumb Ln, Reno            4.1
# 87                 1000 Ted Johnson Pkwy, Greensboro            4.4
# 88                   3400 E Sky Harbor Blvd, Phoenix            3.9
# 89                           2100 NW 42nd Ave, Miami            3.7
# 90                     2400 Aviation Dr, DFW Airport            3.8
# 91                   3400 E Sky Harbor Blvd, Phoenix            3.9
# 92                     2400 Aviation Dr, DFW Airport            3.8
# 93                         2200 Norview Ave, Norfolk            3.6
# 94                 5757 Wayne Newton Blvd, Las Vegas            3.9
# 95                                     San Francisco            4.1
# 96               9430 Jackie Cochran Dr, Baton Rouge            3.9
# 97            1 Richard E Byrd Terminal Dr, Richmond            4.1
# 98                               County Rd 46, Boise
# 99                                           Ontario            4.2
#
# [100 rows x 7 columns]

# %%
cities_pd.sort_values('Airport Rating')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-d90440873cd9> in <module>()
# ----> 1 cities_pd.sort_values('Airport Rating')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    3199
#    3200             indexer = nargsort(k, kind=kind, ascending=ascending,
# -> 3201                                na_position=na_position)
#    3202
#    3203         new_data = self._data.take(indexer,
#
# ~\Anaconda3\lib\site-packages\pandas\core\sorting.py in nargsort(items, kind, ascending, na_position)
#     245         non_nans = non_nans[::-1]
#     246         non_nan_idx = non_nan_idx[::-1]
# --> 247     indexer = non_nan_idx[non_nans.argsort(kind=kind)]
#     248     if not ascending:
#     249         indexer = indexer[::-1]
#
# TypeError: '<' not supported between instances of 'float' and 'str'
